# %% [markdown]
# # **Downlaod**
#
# **Pretrained Model Weight**
# - https://drive.google.com/file/d/108vHV2f8HwtzLvvph9ZGw3EXKvn1EspV/view?usp=sharing
#
# **Tensorboard log (Train / Valid)**
# - https://drive.google.com/file/d/1akasKuYLQTtR83vwKwS_fLFVs4Nbwi1G/view?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/YOLO-v1-tf2
# Out:
# /content/drive/MyDrive/Colab_Notebooks/YOLO-v1-tf2

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1VIwDr76Vhn799l-MfxTVWTyrMX6O9wDE/Colab_Notebooks/YOLO-v1-tf2

# %%
# !python3 train.py
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
# Dl Completed...:   0% 0/2 [01:08<?, ? url/s]
# Dl Size...:  75% 2770/3671 [01:08<00:23, 38.15 MiB/s]
#
# Extraction completed...: 0 file [01:08, ? file/s]
# Dl Completed...:   0% 0/2 [01:08<?, ? url/s]
# Dl Size...:  75% 2771/3671 [01:08<00:23, 38.57 MiB/s]
#
# Dl Completed...:   0% 0/2 [01:08<?, ? url/s]
# Dl Size...:  76% 2772/3671 [01:08<00:23, 38.57 MiB/s]
#
# Dl Completed...:   0% 0/2 [01:08<?, ? url/s]
# Dl Size...:  76% 2773/3671 [01:08<00:23, 38.57 MiB/s]
#
# Dl Completed...:   0% 0/2 [01:08<?, ? url/s]
# Dl Size...:  76% 2774/3671 [01:08<00:23, 38.57 MiB/s]
#
# Dl Completed...:   0% 0/2 [01:08<?, ? url/s]
# Dl Size...:  76% 2775/3671 [01:08<00:23, 38.57 MiB/s]
#
# Extraction completed...: 0 file [01:08, ? file/s]
# Dl Completed...:   0% 0/2 [01:08<?, ? url/s]
# Dl Size...:  76% 2776/3671 [01:08<00:23, 38.55 MiB/s]
#
# Dl Completed...:   0% 0/2 [01:08<?, ? url/s]
# Dl Size...:  76% 2777/3671 [01:08<00:23, 38.55 MiB/s]
#
# ...

# %%
# 텐서보드 로그 확인
# !tensorboard --logdir=tensorboard_log
# Out:
# 2021-10-07 13:42:00.633835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-07 13:42:00.642924: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-07 13:42:00.643744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# TensorBoard 2.6.0 at http://localhost:8088/ (Press CTRL+C to quit)

# %%
# 학습이 다 끝난 후 저장된 파라미터를 활용해서 evaluate.py 실행
# !python evaluate.py
# Out:
# 2021-10-13 17:55:16.363357: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2021-10-13 17:55:16.569825: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2021-10-13 17:55:16.768296: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2021-10-13 17:55:17.022910: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# ...
